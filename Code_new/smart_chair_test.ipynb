# %%
import sys
import importlib

# %%
import sys
sys.path.append('/content')

import tfNN
import importlib; importlib.reload(tfNN)

print(dir(tfNN))  # checking stuff
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'h5py', 'intList', 'layerNum', 'loadWeights', 'load_model', 'model', 'os', 'tf', 'tfNN']

# %%
model = tfNN.load_model(debug=True)
# model.save('/content/my_saved_model')
# Out:
# layerName: fc_1_
#     numVars: 2
#     layerIdx= 2
#     varName: ['bias']
#         shp: [32]
#         weightNum: 1
#     varName: ['kernel']
#         shp: [1033, 32]
#         weightNum: 0
# Copying variable of shape:
# (1033, 32)
# Assignment successful.
# Set variable value:
# <Variable path=fc_1_/kernel, shape=(1033, 32), dtype=float32, value=[[-0.14764841 -0.12489821  0.05672754 ...  0.19759959  0.18919782
#    0.19832608]
#  [-0.03656842 -0.08738466  0.02178314 ...  0.16890389  0.03904117
#    0.09858554]
#  [-0.07512572  0.00404997  0.03083288 ...  0.03638967  0.06493056
#    0.01833717]
#  ...
#  [ 0.10910134  0.16706409  0.567374   ...  0.07816883  0.15615794
#   -0.09884494]
#  [ 0.02102293 -0.00589977  0.07499372 ...  0.01447941  0.06537958
#   -0.03490488]
#  [-0.19669294  0.00557328  0.29460767 ... -0.05612946 -0.5052592
#    0.06650513]]>
# Copying variable of shape:
# (32,)
# Assignment successful.
# Set variable value:
# ...
